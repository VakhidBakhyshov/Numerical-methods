# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = 'out1.txt'  
df = pd.read_csv(file_path, sep='\s+', header=0, names=['x', 'f(x)', 'Pn', 'err'])

plt.figure(figsize=(9, 4))
plt.plot(df['x'][:-1], df['f(x)'][:-1], marker='o', linestyle='-', color='b', label='f(x)')
plt.plot(df['x'][:-1], df['Pn'][:-1], marker='s', linestyle='--', color='r', label='Pn')


plt.title('Graphs Pn')
plt.xlabel('x')
plt.ylabel('Values')

plt.legend()

plt.savefig('graphsPn.png')
plt.show()




file_path = 'out2.txt'  
df = pd.read_csv(file_path, sep='\s+', header=0, names=['x', 'f(x)', 'Ln', 'err'])


plt.figure(figsize=(9, 4))
plt.plot(df['x'], df['f(x)'], marker='o', linestyle='-', color='b', label='f(x)')
plt.plot(df['x'], df['Ln'], marker='s', linestyle='--', color='r', label='Ln')


plt.title('Graphs Ln')
plt.xlabel('x')
plt.ylabel('Values')

plt.legend()

plt.savefig('graphsLn.png')
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HONOR\AppData\Local\Temp\ipykernel_19104\3947700777.py:5: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_path, sep='\s+', header=0, names=['x', 'f(x)', 'Pn', 'err'])
# C:\Users\HONOR\AppData\Local\Temp\ipykernel_19104\3947700777.py:25: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(file_path, sep='\s+', header=0, names=['x', 'f(x)', 'Ln', 'err'])
